# %% [markdown]
# <a href="https://colab.research.google.com/github/ronee12/Computer-Vision-Deep-learning-Work-Shop/blob/master/Image_Augmentation_with_Keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
import numpy as np
from keras.preprocessing.image import load_img

img = load_img('bird.jpg')

# %%
print(img.size)
print(img.mode)
print(img.format)
# Out:
# (640, 399)
# RGB
# JPEG

# %%
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
from keras.preprocessing.image import img_to_array
from numpy import expand_dims

data = img_to_array(img)
print(data.shape)
samples = expand_dims(data,0)
print(samples.shape)
# Out:
# (399, 640, 3)
# (1, 399, 640, 3)

# %%
datagen = ImageDataGenerator(height_shift_range=0.5,width_shift_range=[-100,100], horizontal_flip=True, vertical_flip=True)
it = datagen.flow(samples,batch_size=2)
print(type(it))
for i in range(9):
  plt.subplot(330+1+i)
  batch = it.next()
  image = batch[0].astype('uint8')
  plt.imshow(image)

plt.show()
# Out:
# <class 'keras.preprocessing.image.NumpyArrayIterator'>
